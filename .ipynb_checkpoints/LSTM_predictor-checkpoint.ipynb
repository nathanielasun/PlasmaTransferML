# %%
import numpy as np
import random
import os
from PlasmaDataset import PlasmaDataset

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset

# %%
DATA_SPLIT = [0.8, 0.1, 0.1] # train/test/val splits
DATA_FRAC = 1
ORG_DATA_DIR = "./org_jtext"
HDF5_DATA_DIR = "./jtext_data/low_freq"

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # For GPU (if you're using one)
    torch.cuda.manual_seed_all(seed)  # If using multi-GPU
    np.random.seed(seed)  # For numpy random numbers
    random.seed(seed)  # For Python's built-in random module
    torch.backends.cudnn.deterministic = True  # Make cuDNN deterministic
    torch.backends.cudnn.benchmark = False  # Ensure consistency
set_seed(327)

# %%
JTEXT_LF = PlasmaDataset(ORG_DATA_DIR, HDF5_DATA_DIR)
JTEXT_LF.initPlasmaDataset()
JTEXT_LF.sourceData(data_split = DATA_SPLIT, data_frac = DATA_FRAC, features=['ip', 'ip_error', 'dx', 'dy'])
# Out:
# {'raw':                                                     ip  \
# 0    [181.3013755922196, 181.86474707159928, 181.14...
# 1    [124.7017594989405, 125.66776922610374, 124.54...
# 2    [168.98310925013598, 168.49994336629987, 171.1...
# 3    [158.35558535174187, 154.97427760181597, 153.5...
# 4    [148.61368843303165, 147.9696443819259, 147.80...
# ..                                                 ...
# 459  [119.38799747326875, 114.71937446947962, 118.6...
# 460  [160.69042014819584, 158.91976196208023, 160.0...
# 461  [182.34802567464178, 177.43714349619296, 180.5...
# 462  [137.90565294751156, 139.83825208325862, 139.2...
# 463  [158.7581430753114, 158.59728101219582, 158.91...
#
#                                               ip_error  \
# 0    [0.0071779686611239445, 0.010253482885636656, ...
# 1    [-0.002391630256524407, 0.005313766849018232, ...
# 2    [-0.0060600466886150854, -0.009114724384548788...
# 3    [0.010559931880790843, -0.011459072734016305, ...
# 4    [-0.010069699649784717, -0.01744461727843682, ...
# ..                                                 ...
# 459  [-0.00512616460350861, -0.046030808265305354, ...
# 460  [0.004296585618228547, -0.006797380165831894, ...
# 461  [0.012876616930480445, -0.01444374302532676, 0...
# 462  [-0.015186810748690459, -0.0011566786221346129...
# 463  [-0.007822319539851767, -0.008844533644283043,...
#
#                                                     dx  \
# 0    [0.3503150527087735, 0.3203994585962118, 0.325...
# 1    [-0.6650363361442517, -0.5783704282895308, -0....
# 2    [-0.5662638233333501, -0.6014313553661985, -0....
# 3    [-0.1388695754663396, -0.22527323496472024, -0...
# 4    [-0.8307090196791544, -0.8330240566839071, -0....
# ..                                                 ...
# 459  [-0.2628807384204723, -0.42208620365498645, -0...
# 460  [0.981045009973398, 0.9623756752441952, 0.9648...
# 461  [0.051099989680758906, 0.013744971667432668, 0...
# 462  [0.6119219164145187, 0.5989430581163302, 0.526...
# 463  [0.8642959957428773, 0.8806865408706227, 0.894...
#
#                                                     dy
# 0    [0.12679027359681994, 0.13199477926851924, 0.0...
# 1    [0.08181010658664867, 0.08103073182475529, 0.0...
# 2    [0.6964469285114697, 0.6370001215184814, 0.633...
# 3    [0.6286721722180604, 0.6445763207576272, 0.628...
# 4    [0.07906589010121245, 0.06519328676579093, 0.0...
# ..                                                 ...
# 459  [0.40079288001834895, 0.3502770042617519, 0.33...
# 460  [0.07628258977688995, 0.04048734428369443, 0.0...
# 461  [0.0920931209121989, 0.09689499875646329, 0.09...
# 462  [0.023461327171332758, 0.047547410838451425, 0...
# 463  [-0.0032625092308751213, -0.012830143825383698...
#
# [464 rows x 4 columns], 'norm': Empty DataFrame
# Columns: []
# Index: [], 'files':                                               0
# 0    ./jtext_data/low_freq/1052000/1052053.hdf5
# 1    ./jtext_data/low_freq/1053700/1053724.hdf5
# 2    ./jtext_data/low_freq/1052800/1052880.hdf5
# 3    ./jtext_data/low_freq/1052500/1052573.hdf5
# 4    ./jtext_data/low_freq/1052500/1052579.hdf5
# ..                                          ...
# 459  ./jtext_data/low_freq/1053100/1053105.hdf5
# 460  ./jtext_data/low_freq/1052400/1052411.hdf5
# 461  ./jtext_data/low_freq/1052300/1052313.hdf5
# 462  ./jtext_data/low_freq/1052900/1052910.hdf5
# 463  ./jtext_data/low_freq/1052400/1052403.hdf5
#
# [464 rows x 1 columns]}
