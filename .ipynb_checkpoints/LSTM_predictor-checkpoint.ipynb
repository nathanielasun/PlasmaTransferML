# %%
import numpy as np
import random
import os
import PlasmaDataset

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset

# %%
DATA_SPLIT = [0.8, 0.1, 0.1] # train/test/val splits
ORG_DATA_DIR = "./org_jtext"
HDF5_DATA_DIR = "./jtext_data/low_freq"
DATA_FRAC = 1

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # For GPU (if you're using one)
    torch.cuda.manual_seed_all(seed)  # If using multi-GPU
    np.random.seed(seed)  # For numpy random numbers
    random.seed(seed)  # For Python's built-in random module
    torch.backends.cudnn.deterministic = True  # Make cuDNN deterministic
    torch.backends.cudnn.benchmark = False  # Ensure consistency

set_seed(327)

# %%
JTEXT_LF = PlasmaDataset.PlasmaDataset(ORG_DATA_DIR, HDF5_DATA_DIR, split=DATA_SPLIT)
JTEXT_LF.createDatastructure(reset=True)
JTEXT_LF.setDataFrac(DATA_FRAC)
JTEXT_LF.organizeData()
# Out:
# Initialized with hdf5 source ./jtext_data/low_freq
# Initialized with organized data directory:  ./org_jtext
# Initialized with data split:  [0.8, 0.1, 0.1]
# Deleted directory: ./org_jtext/test
# Deleted directory: ./org_jtext/train
# Deleted directory: ./org_jtext/val
# Deleted all subdirectories in  ./org_jtext
# Added new dataset 'train'
# Added new dataset 'test'
# Added new dataset 'val'
# Added ./org_jtext/train directory to data directory
# Added ./org_jtext/test directory to data directory
# Added ./org_jtext/val directory to data directory
# Created train/test/val dirs at:
# ./org_jtext/train
#  ./org_jtext/test
#  ./org_jtext/val
#
# Set data fraction to:  1
# HDF5 files sourced from  ./jtext_data/low_freq
# Preview:  ['./jtext_data/low_freq/1052700/1052793.hdf5', './jtext_data/low_freq/1052700/1052782.hdf5', './jtext_data/low_freq/1052700/1052794.hdf5', './jtext_data/low_freq/1052700/1052795.hdf5', './jtext_data/low_freq/1052700/1052783.hdf5']
# 464 training shots 80.0 %
# ...

# %%
JTEXT_LF.sourceDataset("train", ['dx'], reset=True)
JTEXT_LF.sourceDataset("val", ['dx'], reset=True)
# Out:
# Wiped 'train' normalized data
# Wiped 'train' raw data
# Wiped dataset 'train'
# Constructed dataset 'train' with 464 files and 2 features
# Wiped 'test' normalized data
# Wiped 'test' raw data
# Wiped dataset 'test'
# Constructed dataset 'test' with 58 files and 2 features
# Wiped 'val' normalized data
# Wiped 'val' raw data
# Wiped dataset 'val'
# Constructed dataset 'val' with 58 files and 2 features

# %%
JTEXT_LF.datasetStats("train")
# Out:
# Wiped train data statistics
# Dataset size: 2
# dx
# dy
# {'dx': (0.2787644289726828, 0.447079600036034), 'dy': (0.09376252356038059, 0.2234877793356932)}

# %%
JTEXT_LF.normalizeDataset("val")
# Out:
# Normalized 'test'
#                                                   0         1         2    \
# 0                                            0.861577  0.960153  1.086291
# 1   [-0.9235484042622348, -0.8302985005816518, -0....       NaN       NaN
# 2   [-1.1090510991361924, -1.120193056267189, -1.0...       NaN       NaN
# 3   [1.9575499788148591, 1.9907970948391047, 1.898...       NaN       NaN
# 4   [0.940266434369189, 1.1165057507546592, 1.1833...       NaN       NaN
# ..                                                ...       ...       ...
# 53  [-0.3804443144293949, -0.2396847703120948, -0....       NaN       NaN
# 54  [-5.631112131300574, -5.666902539698661, -5.72...       NaN       NaN
# 55  [-0.26374524562140517, -0.07982641226438864, -...       NaN       NaN
# 56  [1.3596983625246781, 1.389578024457297, 1.4965...       NaN       NaN
# 57  [-0.43572090127988305, -0.3958712177687058, -0...       NaN       NaN
#
# ...
